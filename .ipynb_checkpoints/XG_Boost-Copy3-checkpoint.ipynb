# %% [markdown]
# ## Boosting Models for Project 4 - Aakash, Nellie, Chaim, and Matt

# %%
import numpy as np 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
data = pd.read_csv('/Users/aakashtandel/Desktop/train_weather2d.csv', index_col='Date')
data = data.drop(['year'], axis=1)
data = data.drop(['NumMosquitos'], axis=1)
data.head()
# Out:
#             Species  Trap  WnvPresent  Year  DayofYear  tmax_x  tmin_x  \
# Date
# 2007-05-29        2     1           0  2007        149      88      60
# 2007-05-29        3     1           0  2007        149      88      60
# 2007-05-29        3     8           0  2007        149      88      60
# 2007-05-29        2    15           0  2007        149      88      60
# 2007-05-29        3    15           0  2007        149      88      60
#
#             tavg_x  depart_x  dewpoint_x      ...       sealevel_y  \
# Date                                          ...
# 2007-05-29     0.0      10.0          58      ...            30.09
# 2007-05-29     0.0      10.0          58      ...            30.09
# 2007-05-29     0.0      10.0          58      ...            30.09
# 2007-05-29     0.0      10.0          58      ...            30.09
# 2007-05-29     0.0      10.0          58      ...            30.09
#
#             resultspeed_y  resultdir_y  avgspeed_y  coollast7  coollast30  \
# Date
# 2007-05-29            5.8           16         7.4       31.0        35.0
# 2007-05-29            5.8           16         7.4       31.0        35.0
# 2007-05-29            5.8           16         7.4       31.0        35.0
# 2007-05-29            5.8           16         7.4       31.0        35.0
# 2007-05-29            5.8           16         7.4       31.0        35.0
#
#             coollast90  preciplast7  preciplast30  preciplast90
# Date
# 2007-05-29         0.0         1.08         0.735           0.0
# 2007-05-29         0.0         1.08         0.735           0.0
# 2007-05-29         0.0         1.08         0.735           0.0
# 2007-05-29         0.0         1.08         0.735           0.0
# 2007-05-29         0.0         1.08         0.735           0.0
#
# [5 rows x 39 columns]

# %%
data.shape
# Out:
# (8475, 39)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8475 entries, 2007-05-29 to 2013-09-26
# Data columns (total 39 columns):
# Species          8475 non-null int64
# Trap             8475 non-null int64
# WnvPresent       8475 non-null int64
# Year             8475 non-null int64
# DayofYear        8475 non-null int64
# tmax_x           8475 non-null int64
# tmin_x           8475 non-null int64
# tavg_x           8475 non-null float64
# depart_x         8475 non-null float64
# dewpoint_x       8475 non-null int64
# wetbulb_x        8475 non-null float64
# heat_x           8475 non-null float64
# cool_x           8475 non-null float64
# preciptotal_x    8475 non-null float64
# stnpressure_x    8475 non-null float64
# sealevel_x       8475 non-null float64
# resultspeed_x    8475 non-null float64
# resultdir_x      8475 non-null int64
# avgspeed_x       8475 non-null float64
# tmax_y           8475 non-null int64
# tmin_y           8475 non-null int64
# tavg_y           8475 non-null float64
# depart_y         8475 non-null float64
# dewpoint_y       8475 non-null int64
# wetbulb_y        8475 non-null float64
# heat_y           8475 non-null float64
# cool_y           8475 non-null float64
# preciptotal_y    8475 non-null float64
# stnpressure_y    8475 non-null float64
# sealevel_y       8475 non-null float64
# resultspeed_y    8475 non-null float64
# resultdir_y      8475 non-null int64
# avgspeed_y       8475 non-null float64
# coollast7        8475 non-null float64
# coollast30       8475 non-null float64
# coollast90       8475 non-null float64
# preciplast7      8475 non-null float64
# preciplast30     8475 non-null float64
# preciplast90     8475 non-null float64
# dtypes: float64(26), int64(13)
# memory usage: 2.6+ MB

# %% [markdown]
# Now that everything is an integer or float it should be easier to model.

# %%
data_test = pd.read_csv('/Users/aakashtandel/Desktop/test_weather3d.csv', index_col='Date')
data_test.head()
# Out:
#             Id  Species  Trap  tmax_x  tmin_x  tavg_x  depart_x  dewpoint_x  \
# Date
# 2008-06-11   1        2     1      86      61     0.0       7.0          56
# 2008-06-11   2        3     1      86      61     0.0       7.0          56
# 2008-06-11   3        1     1      86      61     0.0       7.0          56
# 2008-06-11   4        4     1      86      61     0.0       7.0          56
# 2008-06-11   5        6     1      86      61     0.0       7.0          56
#
#             wetbulb_x  heat_x    ...      resultdir_y  avgspeed_y  year  \
# Date                             ...
# 2008-06-11       64.0     0.0    ...               18        10.4  2008
# 2008-06-11       64.0     0.0    ...               18        10.4  2008
# 2008-06-11       64.0     0.0    ...               18        10.4  2008
# 2008-06-11       64.0     0.0    ...               18        10.4  2008
# 2008-06-11       64.0     0.0    ...               18        10.4  2008
#
#             coollast7  coollast30  coollast90  preciplast7  preciplast30  \
# Date
# 2008-06-11       64.0        12.0         0.0         2.14          1.65
# 2008-06-11       64.0        12.0         0.0         2.14          1.65
# 2008-06-11       64.0        12.0         0.0         2.14          1.65
# 2008-06-11       64.0        12.0         0.0         2.14          1.65
# 2008-06-11       64.0        12.0         0.0         2.14          1.65
#
#             preciplast90  DayofYear
# Date
# 2008-06-11         2.995        163
# 2008-06-11         2.995        163
# 2008-06-11         2.995        163
# 2008-06-11         2.995        163
# 2008-06-11         2.995        163
#
# [5 rows x 39 columns]

# %%
data_test.shape
# Out:
# (116293, 39)

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116293 entries, 2008-06-11 to 2014-10-02
# Data columns (total 39 columns):
# Id               116293 non-null int64
# Species          116293 non-null int64
# Trap             116293 non-null int64
# tmax_x           116293 non-null int64
# tmin_x           116293 non-null int64
# tavg_x           116293 non-null float64
# depart_x         116293 non-null float64
# dewpoint_x       116293 non-null int64
# wetbulb_x        116293 non-null float64
# heat_x           116293 non-null float64
# cool_x           116293 non-null float64
# preciptotal_x    116293 non-null float64
# stnpressure_x    116293 non-null float64
# sealevel_x       116293 non-null float64
# resultspeed_x    116293 non-null float64
# resultdir_x      116293 non-null int64
# avgspeed_x       116293 non-null float64
# tmax_y           116293 non-null int64
# tmin_y           116293 non-null int64
# tavg_y           116293 non-null float64
# depart_y         116293 non-null float64
# dewpoint_y       116293 non-null int64
# wetbulb_y        116293 non-null float64
# heat_y           116293 non-null float64
# cool_y           116293 non-null float64
# preciptotal_y    116293 non-null float64
# stnpressure_y    116293 non-null float64
# sealevel_y       116293 non-null float64
# resultspeed_y    116293 non-null float64
# resultdir_y      116293 non-null int64
# avgspeed_y       116293 non-null float64
# year             116293 non-null int64
# coollast7        116293 non-null float64
# coollast30       116293 non-null float64
# coollast90       116293 non-null float64
# preciplast7      116293 non-null float64
# preciplast30     116293 non-null float64
# preciplast90     116293 non-null float64
# DayofYear        116293 non-null int64
# dtypes: float64(26), int64(13)
# memory usage: 35.5+ MB

# %%
data_test = data_test.rename(columns={'year':'Year'})

# %%
data_test.shape
# Out:
# (116293, 39)

# %%
data = data.reindex_axis(sorted(data.columns), axis=1)
data_test = data_test.reindex_axis(sorted(data_test.columns), axis=1)

# %%
print (data.info())
print (data_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8475 entries, 2007-05-29 to 2013-09-26
# Data columns (total 39 columns):
# DayofYear        8475 non-null int64
# Species          8475 non-null int64
# Trap             8475 non-null int64
# WnvPresent       8475 non-null int64
# Year             8475 non-null int64
# avgspeed_x       8475 non-null float64
# avgspeed_y       8475 non-null float64
# cool_x           8475 non-null float64
# cool_y           8475 non-null float64
# coollast30       8475 non-null float64
# coollast7        8475 non-null float64
# coollast90       8475 non-null float64
# depart_x         8475 non-null float64
# depart_y         8475 non-null float64
# dewpoint_x       8475 non-null int64
# dewpoint_y       8475 non-null int64
# heat_x           8475 non-null float64
# heat_y           8475 non-null float64
# preciplast30     8475 non-null float64
# preciplast7      8475 non-null float64
# preciplast90     8475 non-null float64
# preciptotal_x    8475 non-null float64
# preciptotal_y    8475 non-null float64
# resultdir_x      8475 non-null int64
# resultdir_y      8475 non-null int64
# resultspeed_x    8475 non-null float64
# resultspeed_y    8475 non-null float64
# sealevel_x       8475 non-null float64
# sealevel_y       8475 non-null float64
# stnpressure_x    8475 non-null float64
# stnpressure_y    8475 non-null float64
# tavg_x           8475 non-null float64
# tavg_y           8475 non-null float64
# tmax_x           8475 non-null int64
# tmax_y           8475 non-null int64
# tmin_x           8475 non-null int64
# tmin_y           8475 non-null int64
# wetbulb_x        8475 non-null float64
# wetbulb_y        8475 non-null float64
# dtypes: float64(26), int64(13)
# memory usage: 2.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 116293 entries, 2008-06-11 to 2014-10-02
# Data columns (total 39 columns):
# DayofYear        116293 non-null int64
# Id               116293 non-null int64
# Species          116293 non-null int64
# Trap             116293 non-null int64
# Year             116293 non-null int64
# avgspeed_x       116293 non-null float64
# avgspeed_y       116293 non-null float64
# cool_x           116293 non-null float64
# cool_y           116293 non-null float64
# coollast30       116293 non-null float64
# coollast7        116293 non-null float64
# coollast90       116293 non-null float64
# depart_x         116293 non-null float64
# depart_y         116293 non-null float64
# dewpoint_x       116293 non-null int64
# dewpoint_y       116293 non-null int64
# heat_x           116293 non-null float64
# heat_y           116293 non-null float64
# preciplast30     116293 non-null float64
# preciplast7      116293 non-null float64
# preciplast90     116293 non-null float64
# preciptotal_x    116293 non-null float64
# preciptotal_y    116293 non-null float64
# resultdir_x      116293 non-null int64
# resultdir_y      116293 non-null int64
# resultspeed_x    116293 non-null float64
# resultspeed_y    116293 non-null float64
# sealevel_x       116293 non-null float64
# sealevel_y       116293 non-null float64
# stnpressure_x    116293 non-null float64
# stnpressure_y    116293 non-null float64
# tavg_x           116293 non-null float64
# tavg_y           116293 non-null float64
# tmax_x           116293 non-null int64
# tmax_y           116293 non-null int64
# tmin_x           116293 non-null int64
# tmin_y           116293 non-null int64
# wetbulb_x        116293 non-null float64
# wetbulb_y        116293 non-null float64
# dtypes: float64(26), int64(13)
# memory usage: 35.5+ MB
# None

# %%
from sklearn.model_selection import train_test_split 
from sklearn.metrics import log_loss, accuracy_score
from collections import Counter

# %%
X = data.drop(['WnvPresent'], axis=1)
y = data[['WnvPresent']]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_features = StandardScaler().fit_transform(X.values)
scaled_features_df = pd.DataFrame(scaled_features, index=X.index, columns=X.columns)
scaled_features_df.head()
# Out:
#             DayofYear   Species      Trap      Year  avgspeed_x  avgspeed_y  \
# Date
# 2007-05-29  -2.098191 -0.181660 -1.655573 -1.163639   -0.384767   -0.052234
# 2007-05-29  -2.098191  0.852302 -1.655573 -1.163639   -0.384767   -0.052234
# 2007-05-29  -2.098191  0.852302 -1.492869 -1.163639   -0.384767   -0.052234
# 2007-05-29  -2.098191 -0.181660 -1.330164 -1.163639   -0.384767   -0.052234
# 2007-05-29  -2.098191  0.852302 -1.330164 -1.163639   -0.384767   -0.052234
#
#               cool_x    cool_y  coollast30  coollast7    ...      \
# Date                                                     ...
# 2007-05-29  0.178858  0.535968    -1.70802  -0.604139    ...
# 2007-05-29  0.178858  0.535968    -1.70802  -0.604139    ...
# 2007-05-29  0.178858  0.535968    -1.70802  -0.604139    ...
# 2007-05-29  0.178858  0.535968    -1.70802  -0.604139    ...
# 2007-05-29  0.178858  0.535968    -1.70802  -0.604139    ...
#
#             stnpressure_x  stnpressure_y    tavg_x    tavg_y    tmax_x  \
# Date
# 2007-05-29       1.183685       1.106717 -0.394484 -0.457129  0.809802
# 2007-05-29       1.183685       1.106717 -0.394484 -0.457129  0.809802
# 2007-05-29       1.183685       1.106717 -0.394484 -0.457129  0.809802
# 2007-05-29       1.183685       1.106717 -0.394484 -0.457129  0.809802
# 2007-05-29       1.183685       1.106717 -0.394484 -0.457129  0.809802
#
#               tmax_y    tmin_x    tmin_y  wetbulb_x  wetbulb_y
# Date
# 2007-05-29  0.779474 -0.269178  0.130585   0.105077   0.221881
# 2007-05-29  0.779474 -0.269178  0.130585   0.105077   0.221881
# 2007-05-29  0.779474 -0.269178  0.130585   0.105077   0.221881
# 2007-05-29  0.779474 -0.269178  0.130585   0.105077   0.221881
# 2007-05-29  0.779474 -0.269178  0.130585   0.105077   0.221881
#
# [5 rows x 38 columns]

# %%
# scaled_target = StandardScaler().fit_transform(y.values)
# scaled_target_df = pd.DataFrame(scaled_target, index=y.index, columns=y.columns)
# scaled_target_df.head()

# %%
sample = pd.DataFrame()
sample['Id'] = data_test['Id']
sample.head()
# Out:
#             Id
# Date
# 2008-06-11   1
# 2008-06-11   2
# 2008-06-11   3
# 2008-06-11   4
# 2008-06-11   5

# %%
data_test = data_test.drop('Id', 1)
scaled_test = StandardScaler().fit_transform(data_test.values)
scaled_test_df = pd.DataFrame(scaled_test, index=data_test.index, columns=data_test.columns)
scaled_test_df.head()
# Out:
#             DayofYear   Species      Trap      Year  avgspeed_x  avgspeed_y  \
# Date
# 2008-06-11  -1.661442 -0.649210 -1.667987 -1.269651    0.770486    0.944145
# 2008-06-11  -1.661442 -0.211128 -1.667987 -1.269651    0.770486    0.944145
# 2008-06-11  -1.661442 -1.087291 -1.667987 -1.269651    0.770486    0.944145
# 2008-06-11  -1.661442  0.226954 -1.667987 -1.269651    0.770486    0.944145
# 2008-06-11  -1.661442  1.103117 -1.667987 -1.269651    0.770486    0.944145
#
#               cool_x    cool_y  coollast30  coollast7    ...      \
# Date                                                     ...
# 2008-06-11  0.349224  0.518555   -2.202139   0.225113    ...
# 2008-06-11  0.349224  0.518555   -2.202139   0.225113    ...
# 2008-06-11  0.349224  0.518555   -2.202139   0.225113    ...
# 2008-06-11  0.349224  0.518555   -2.202139   0.225113    ...
# 2008-06-11  0.349224  0.518555   -2.202139   0.225113    ...
#
#             stnpressure_x  stnpressure_y   tavg_x    tavg_y    tmax_x  \
# Date
# 2008-06-11        0.06485       0.089946 -0.37034 -0.351451  0.648296
# 2008-06-11        0.06485       0.089946 -0.37034 -0.351451  0.648296
# 2008-06-11        0.06485       0.089946 -0.37034 -0.351451  0.648296
# 2008-06-11        0.06485       0.089946 -0.37034 -0.351451  0.648296
# 2008-06-11        0.06485       0.089946 -0.37034 -0.351451  0.648296
#
#              tmax_y   tmin_x    tmin_y  wetbulb_x  wetbulb_y
# Date
# 2008-06-11  0.62555 -0.05619  0.394984   0.177482   0.060343
# 2008-06-11  0.62555 -0.05619  0.394984   0.177482   0.060343
# 2008-06-11  0.62555 -0.05619  0.394984   0.177482   0.060343
# 2008-06-11  0.62555 -0.05619  0.394984   0.177482   0.060343
# 2008-06-11  0.62555 -0.05619  0.394984   0.177482   0.060343
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Simple Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(scaled_features_df, y)
dt_prob = dt.predict_proba(scaled_test)[:,1]
dt_nodes = dt.tree_.node_count
print ('Decision Tree')
print ('Number of Nodes: ', str(dt_nodes))
sample['WnvPresent_DecisionTree'] = dt_prob
# Out:
# Decision Tree
# ('Number of Nodes: ', '1853')

# %%
sample.head()
# Out:
#             Id  WnvPresent_DecisionTree
# Date
# 2008-06-11   1                      0.0
# 2008-06-11   2                      0.0
# 2008-06-11   3                      0.0
# 2008-06-11   4                      0.0
# 2008-06-11   5                      0.0

# %% [markdown]
# ### AdaBoost Classifier

# %%
adaboost = AdaBoostClassifier(
            base_estimator=DecisionTreeClassifier(max_depth=1), 
            algorithm='SAMME', n_estimators=1000, random_state=100)
adaboost.fit(scaled_features_df, y)
ada_pred = adaboost.predict(scaled_test)
ada_pred_proba = adaboost.predict_proba(scaled_test)[:,1]
print ('AdaBoost')
sample['WnvPresent_Ada'] = ada_pred_proba
sample.head()
# Out:
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoost
#             Id  WnvPresent_DecisionTree  WnvPresent_Ada
# Date
# 2008-06-11   1                      0.0        0.385928
# 2008-06-11   2                      0.0        0.385928
# 2008-06-11   3                      0.0        0.385928
# 2008-06-11   4                      0.0        0.385928
# 2008-06-11   5                      0.0        0.384303

# %% [markdown]
# ### Gradient Boost Classifier

# %%
gbc = GradientBoostingClassifier(
            max_depth=1, warm_start=True, 
            n_estimators=1000, random_state=100)
gbc.fit(scaled_features_df, y)
gbc_pred = gbc.predict(scaled_test)
gbc_pred_proba = gbc.predict_proba(scaled_test)[:,1]
print ('Gradient Boost')
sample['WnvPresent_gradientboost'] = gbc_pred_proba
sample.head()
# Out:
# Gradient Boost
#             Id  WnvPresent_DecisionTree  WnvPresent_Ada  \
# Date
# 2008-06-11   1                      0.0        0.385928
# 2008-06-11   2                      0.0        0.385928
# 2008-06-11   3                      0.0        0.385928
# 2008-06-11   4                      0.0        0.385928
# 2008-06-11   5                      0.0        0.384303
#
#             WnvPresent_gradientboost
# Date
# 2008-06-11                  0.000306
# 2008-06-11                  0.000306
# 2008-06-11                  0.000339
# 2008-06-11                  0.000306
# 2008-06-11                  0.000144

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

# %%
# params = {'objective':'binary:logistic', 'max_depth':2, 'silent':1, 'eta':1}
# num_rounds = 5
# dtrain = xgb.DMatrix(scaled_features_df, label=y)
# dtest = xgb.DMatrix(scaled_test)

# %%
# boosted = xgb.train(params, dtrain, num_rounds)

# %%
## preds_prob = boosted.predict(dtest)
# sample['WnvPresent_xgboost'] = preds_prob
# sample.head()

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.cross_validation import StratifiedKFold
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import auc
# Out:
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
print (scaled_features_df.shape)
print (y.shape)
y.head()
# Out:
# (8475, 38)
# (8475, 1)
#             WnvPresent
# Date
# 2007-05-29           0
# 2007-05-29           0
# 2007-05-29           0
# 2007-05-29           0
# 2007-05-29           0

# %%
gbm = xgb.XGBClassifier()
parameters = {'n_jobs':[-1,4], 
              'objective':['binary:logistic'],
              'learning_rate': [0.05, 0.1, 0.3, 1], 
              'max_depth': [2, 6, 9, 12],
              'min_child_weight': [11],
              'silent': [1],
              'subsample': [0.8, 0.9, 1.0],
              'colsample_bytree': [0.7, 0.9, 1.0],
              'n_estimators': [5,10,100,100], 
              }
clf = GridSearchCV(gbm, parameters, n_jobs=5, 
                   cv=StratifiedKFold(y['WnvPresent'], n_folds=5, shuffle=True), verbose=4,
                   scoring='roc_auc', refit=True)
clf.fit(scaled_features_df, y)
# print (clf.best_params_)
# print (clf.best_estimator_)
best = clf.best_estimator_
preds = best.predict_proba(scaled_test)[:,1]
print (preds)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.786664 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.796402 -   0.2s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.789770 -   0.1s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.796799 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.788847 -   0.1s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.787325 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.791645 -   0.1s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.797272 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.774612 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.803589 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.812137 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.791449 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.807219 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.796402 -   0.1s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.791425 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.788847 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.774526 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.786664 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.789770 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.787325 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.796799 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.797272 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.803589 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.791425 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.791645 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.774526 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.774612 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.812137 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.791449 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.807219 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.798547 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.809775 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.812803 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [Parallel(n_jobs=5)]: Done  20 tasks      | elapsed:    0.6s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.807140 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.794434 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.801590 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.791860 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.799282 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.796073 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.807140 -   0.1s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.810423 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.786303 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.814342 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.801590 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.794407 -   0.1s
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.791860 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.785677 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.798547 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.809775 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.812803 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.799282 -   0.1s
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.796073 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.807140 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.794407 -   0.1s
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.785677 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.807140 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.794434 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.810423 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.786303 -   0.1s
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=10, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.814342 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.837092 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.829289 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.862339 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.852584 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.839096 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.823010 -   0.5s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.848726 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.836353 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.860180 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.835463 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.835472 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.848613 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.862754 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.823010 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.835463 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.828435 -   0.6s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.837646 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.837092 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.852584 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.862339 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.836353 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.848726 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.860180 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.828435 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.837646 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.829289 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.839096 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.835472 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.848613 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.862754 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.852584 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.837092 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.862339 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.829289 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.839096 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.836353 -   0.5s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.835463 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.823010 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.848726 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.860180 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.837646 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.835472 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.848613 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.862754 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.837092 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.828435 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.823010 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.852584 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.835463 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.862339 -   0.6s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.836353 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.829289 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.848726 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.839096 -   0.6s
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.860180 -   0.5s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.835472 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.828435 -   0.5s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.848613 -   0.6s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6, score=0.818606 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6, score=0.815472 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6, score=0.826205 -   0.1s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6, score=0.835518 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6, score=0.823384 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.862754 -   0.6s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6, score=0.813649 -   0.1s
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.837646 -   0.6s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6, score=0.823359 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6, score=0.847397 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6, score=0.816450 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.9, objective=binary:logistic, max_depth=6, score=0.837533 -   0.1s
# [CV] n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6, score=0.821553 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6, score=0.820395 -   0.1s
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6, score=0.843852 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6, score=0.831086 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=-1, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=1.0, objective=binary:logistic, max_depth=6, score=0.849890 -   0.1s
# [CV] n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6
# [CV]  n_jobs=4, colsample_bytree=0.7, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=5, subsample=0.8, objective=binary:logistic, max_depth=6, score=0.818606 -   0.1s
# ...
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.850720 -   0.8s
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.828045 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.841581 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.862151 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.838654 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.824894 -   0.8s
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.855290 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.837266 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.862181 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.836265 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.828598 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.851751 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.838946 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.861589 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.833541 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.828045 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.850720 -   0.8s
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.841581 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.862151 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.838654 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.824894 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.855290 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.837266 -   0.9s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.862181 -   0.9s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.836265 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.851751 -   0.8s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.838946 -   0.9s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.828598 -   1.0s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2, score=0.861589 -   0.9s
# [CV] n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.833541 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.828045 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.841581 -   0.8s
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.850720 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=-1, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2, score=0.862151 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.838654 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.824894 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.837266 -   0.8s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.855290 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV]  n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.8, objective=binary:logistic, max_depth=2, score=0.862181 -   0.9s
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=0.9, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# [CV] n_jobs=4, colsample_bytree=1.0, silent=1, learning_rate=0.05, min_child_weight=11, n_estimators=100, subsample=1.0, objective=binary:logistic, max_depth=2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-2d110bf0f56d> in <module>()
#      13                    cv=StratifiedKFold(y['WnvPresent'], n_folds=5, shuffle=True), verbose=4,
#      14                    scoring='roc_auc', refit=True)
# ---> 15 clf.fit(scaled_features_df, y)
#      16 # print (clf.best_params_)
#      17 # print (clf.best_estimator_)
#
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in fit(self, X, y)
#     827
#     828         """
# --> 829         return self._fit(X, y, ParameterGrid(self.param_grid))
#     830
#     831
#
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/grid_search.pyc in _fit(self, X, y, parameter_iterable)
#     571                                     self.fit_params, return_parameters=True,
#     572                                     error_score=self.error_score)
# --> 573                 for parameters in parameter_iterable
#     574                 for train, test in cv)
#     575
#
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     766                 # consumption.
#     767                 self._iterating = False
# --> 768             self.retrieve()
#     769             # Make sure that we get a last message telling us we are done
#     770             elapsed_time = time.time() - self._start_time
#
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     717                     ensure_ready = self._managed_backend
#     718                     backend.abort_everything(ensure_ready=ensure_ready)
# --> 719                 raise exception
#     720
#     721     def __call__(self, iterable):
#
# KeyboardInterrupt:

# %%
sample['WnvPresent_xgboost_cv'] = predictions
sample.head()

# %%
sample.shape

# %%
sample_xgboost = sample.copy(deep=True)
sample_xgboost = sample_xgboost.drop(['WnvPresent_DecisionTree', 'WnvPresent_Ada', 'WnvPresent_gradientboost', 'WnvPresent_xgboost'], 1)

# %%
sample_xgboost.set_index('Id', inplace=True)

# %%
sample_xgboost = sample_xgboost.sort_index(axis=1, ascending=True)

# %%
sample_xgboost.head()
# Out:
#     WnvPresent_xgboost_cv
# Id
# 1                0.005909
# 2                0.005909
# 3                0.005909
# 4                0.005909
# 5                0.005909

# %%
sample_xgboost = sample_xgboost.rename(columns={'WnvPresent_xgboost_cv': 'WnvPresent'})
sample_xgboost.head()
# Out:
#     WnvPresent
# Id
# 1     0.005909
# 2     0.005909
# 3     0.005909
# 4     0.005909
# 5     0.005909

# %%
sample_xgboost.to_csv('sample_xgboost.csv')

# %%
# labels = dtest.get_label()
# preds = preds_prob > 0.5 
# correct = 0 
# for each in range(len(preds)):
#     if (labels[each]==preds[each]):
#         correct += 1
# print ('Correctly predicted: ', str(correct), '/', str(len(preds)))

# %%
# from xgboost.sklearn import XGBClassifier 
# boost = XGBClassifier(**params).fit(X_train, y_train)

# %%
# acc = accuracy_score(y_test, preds)
# acc
