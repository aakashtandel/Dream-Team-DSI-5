# %% [markdown]
# ## Boosting Models for Project 4 - Aakash, Nellie, Chaim, and Matt

# %%
import numpy as np 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
data = pd.read_csv('/Users/aakashtandel/Desktop/train_weather2e.csv', index_col='Date')
data.head()
# Out:
#             Species  Trap   Latitude  Longitude  NumMosquitos  WnvPresent  \
# Date
# 2007-05-29        2     1  41.954690 -87.800991             1           0
# 2007-05-29        3     1  41.954690 -87.800991             1           0
# 2007-05-29        3     8  41.994991 -87.769279             1           0
# 2007-05-29        2    15  41.974089 -87.824812             1           0
# 2007-05-29        3    15  41.974089 -87.824812             4           0
#
#             Year  DayofYear  tmax_x  tmin_x    ...     year  coollast7  \
# Date                                           ...
# 2007-05-29  2007        149      88      60    ...     2007       31.0
# 2007-05-29  2007        149      88      60    ...     2007       31.0
# 2007-05-29  2007        149      88      60    ...     2007       31.0
# 2007-05-29  2007        149      88      60    ...     2007       31.0
# 2007-05-29  2007        149      88      60    ...     2007       31.0
#
#             coollast30  coollast90  preciplast7  preciplast30  preciplast90  \
# Date
# 2007-05-29        35.0         0.0         1.08         0.735           0.0
# 2007-05-29        35.0         0.0         1.08         0.735           0.0
# 2007-05-29        35.0         0.0         1.08         0.735           0.0
# 2007-05-29        35.0         0.0         1.08         0.735           0.0
# 2007-05-29        35.0         0.0         1.08         0.735           0.0
#
#             wblast7  wblast30  wblast90
# Date
# 2007-05-29    412.0    1149.0       0.0
# 2007-05-29    412.0    1149.0       0.0
# 2007-05-29    412.0    1149.0       0.0
# 2007-05-29    412.0    1149.0       0.0
# 2007-05-29    412.0    1149.0       0.0
#
# [5 rows x 46 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8475 entries, 2007-05-29 to 2013-09-26
# Data columns (total 46 columns):
# Species          8475 non-null int64
# Trap             8475 non-null int64
# Latitude         8475 non-null float64
# Longitude        8475 non-null float64
# NumMosquitos     8475 non-null int64
# WnvPresent       8475 non-null int64
# Year             8475 non-null int64
# DayofYear        8475 non-null int64
# tmax_x           8475 non-null int64
# tmin_x           8475 non-null int64
# tavg_x           8475 non-null float64
# depart_x         8475 non-null float64
# dewpoint_x       8475 non-null int64
# wetbulb_x        8475 non-null float64
# heat_x           8475 non-null float64
# cool_x           8475 non-null float64
# preciptotal_x    8475 non-null float64
# stnpressure_x    8475 non-null float64
# sealevel_x       8475 non-null float64
# resultspeed_x    8475 non-null float64
# resultdir_x      8475 non-null int64
# avgspeed_x       8475 non-null float64
# tmax_y           8475 non-null int64
# tmin_y           8475 non-null int64
# tavg_y           8475 non-null float64
# depart_y         8475 non-null float64
# dewpoint_y       8475 non-null int64
# wetbulb_y        8475 non-null float64
# heat_y           8475 non-null float64
# cool_y           8475 non-null float64
# preciptotal_y    8475 non-null float64
# stnpressure_y    8475 non-null float64
# sealevel_y       8475 non-null float64
# resultspeed_y    8475 non-null float64
# resultdir_y      8475 non-null int64
# avgspeed_y       8475 non-null float64
# year             8475 non-null int64
# coollast7        8475 non-null float64
# coollast30       8475 non-null float64
# coollast90       8475 non-null float64
# preciplast7      8475 non-null float64
# preciplast30     8475 non-null float64
# preciplast90     8475 non-null float64
# wblast7          8475 non-null float64
# wblast30         8475 non-null float64
# wblast90         8475 non-null float64
# dtypes: float64(31), int64(15)
# memory usage: 3.0+ MB

# %% [markdown]
# Now that everything is an integer or float it should be easier to model.

# %%
data_test = pd.read_csv('/Users/aakashtandel/Desktop/test_weather3e.csv', index_col='Date')
data_test.head()
# Out:
#             Id  Species  Trap  Latitude  Longitude  tmax_x  tmin_x  tavg_x  \
# Date
# 2008-06-11   1        2     1  41.95469 -87.800991      86      61     0.0
# 2008-06-11   2        3     1  41.95469 -87.800991      86      61     0.0
# 2008-06-11   3        1     1  41.95469 -87.800991      86      61     0.0
# 2008-06-11   4        4     1  41.95469 -87.800991      86      61     0.0
# 2008-06-11   5        6     1  41.95469 -87.800991      86      61     0.0
#
#             depart_x  dewpoint_x    ...      coollast7  coollast30  \
# Date                                ...
# 2008-06-11       7.0          56    ...           64.0        12.0
# 2008-06-11       7.0          56    ...           64.0        12.0
# 2008-06-11       7.0          56    ...           64.0        12.0
# 2008-06-11       7.0          56    ...           64.0        12.0
# 2008-06-11       7.0          56    ...           64.0        12.0
#
#             coollast90  preciplast7  preciplast30  preciplast90  wblast7  \
# Date
# 2008-06-11         0.0         2.14          1.65         2.995    479.0
# 2008-06-11         0.0         2.14          1.65         2.995    479.0
# 2008-06-11         0.0         2.14          1.65         2.995    479.0
# 2008-06-11         0.0         2.14          1.65         2.995    479.0
# 2008-06-11         0.0         2.14          1.65         2.995    479.0
#
#             wblast30  wblast90  DayofYear
# Date
# 2008-06-11    1187.0     591.5        163
# 2008-06-11    1187.0     591.5        163
# 2008-06-11    1187.0     591.5        163
# 2008-06-11    1187.0     591.5        163
# 2008-06-11    1187.0     591.5        163
#
# [5 rows x 44 columns]

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 116293 entries, 2008-06-11 to 2014-10-02
# Data columns (total 44 columns):
# Id               116293 non-null int64
# Species          116293 non-null int64
# Trap             116293 non-null int64
# Latitude         116293 non-null float64
# Longitude        116293 non-null float64
# tmax_x           116293 non-null int64
# tmin_x           116293 non-null int64
# tavg_x           116293 non-null float64
# depart_x         116293 non-null float64
# dewpoint_x       116293 non-null int64
# wetbulb_x        116293 non-null float64
# heat_x           116293 non-null float64
# cool_x           116293 non-null float64
# preciptotal_x    116293 non-null float64
# stnpressure_x    116293 non-null float64
# sealevel_x       116293 non-null float64
# resultspeed_x    116293 non-null float64
# resultdir_x      116293 non-null int64
# avgspeed_x       116293 non-null float64
# tmax_y           116293 non-null int64
# tmin_y           116293 non-null int64
# tavg_y           116293 non-null float64
# depart_y         116293 non-null float64
# dewpoint_y       116293 non-null int64
# wetbulb_y        116293 non-null float64
# heat_y           116293 non-null float64
# cool_y           116293 non-null float64
# preciptotal_y    116293 non-null float64
# stnpressure_y    116293 non-null float64
# sealevel_y       116293 non-null float64
# resultspeed_y    116293 non-null float64
# resultdir_y      116293 non-null int64
# avgspeed_y       116293 non-null float64
# year             116293 non-null int64
# coollast7        116293 non-null float64
# coollast30       116293 non-null float64
# coollast90       116293 non-null float64
# preciplast7      116293 non-null float64
# preciplast30     116293 non-null float64
# preciplast90     116293 non-null float64
# wblast7          116293 non-null float64
# wblast30         116293 non-null float64
# wblast90         116293 non-null float64
# DayofYear        116293 non-null int64
# dtypes: float64(31), int64(13)
# memory usage: 39.9+ MB

# %%
data_test = data_test.rename(columns={'year': 'Year'})
data = data.drop(['year', 'NumMosquitos', 'Latitude', 'Longitude'], axis=1)
data_test = data_test.drop(['Latitude', 'Longitude'], axis=1)

# %%
data = data.reindex_axis(sorted(data.columns), axis=1)
data_test = data_test.reindex_axis(sorted(data_test.columns), axis=1)

# %%
print (data.info())
print (data_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8475 entries, 2007-05-29 to 2013-09-26
# Data columns (total 42 columns):
# DayofYear        8475 non-null int64
# Species          8475 non-null int64
# Trap             8475 non-null int64
# WnvPresent       8475 non-null int64
# Year             8475 non-null int64
# avgspeed_x       8475 non-null float64
# avgspeed_y       8475 non-null float64
# cool_x           8475 non-null float64
# cool_y           8475 non-null float64
# coollast30       8475 non-null float64
# coollast7        8475 non-null float64
# coollast90       8475 non-null float64
# depart_x         8475 non-null float64
# depart_y         8475 non-null float64
# dewpoint_x       8475 non-null int64
# dewpoint_y       8475 non-null int64
# heat_x           8475 non-null float64
# heat_y           8475 non-null float64
# preciplast30     8475 non-null float64
# preciplast7      8475 non-null float64
# preciplast90     8475 non-null float64
# preciptotal_x    8475 non-null float64
# preciptotal_y    8475 non-null float64
# resultdir_x      8475 non-null int64
# resultdir_y      8475 non-null int64
# resultspeed_x    8475 non-null float64
# resultspeed_y    8475 non-null float64
# sealevel_x       8475 non-null float64
# sealevel_y       8475 non-null float64
# stnpressure_x    8475 non-null float64
# stnpressure_y    8475 non-null float64
# tavg_x           8475 non-null float64
# tavg_y           8475 non-null float64
# tmax_x           8475 non-null int64
# tmax_y           8475 non-null int64
# tmin_x           8475 non-null int64
# tmin_y           8475 non-null int64
# wblast30         8475 non-null float64
# wblast7          8475 non-null float64
# wblast90         8475 non-null float64
# wetbulb_x        8475 non-null float64
# wetbulb_y        8475 non-null float64
# dtypes: float64(29), int64(13)
# memory usage: 2.8+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 116293 entries, 2008-06-11 to 2014-10-02
# Data columns (total 42 columns):
# DayofYear        116293 non-null int64
# Id               116293 non-null int64
# Species          116293 non-null int64
# Trap             116293 non-null int64
# Year             116293 non-null int64
# avgspeed_x       116293 non-null float64
# avgspeed_y       116293 non-null float64
# cool_x           116293 non-null float64
# cool_y           116293 non-null float64
# coollast30       116293 non-null float64
# coollast7        116293 non-null float64
# coollast90       116293 non-null float64
# depart_x         116293 non-null float64
# depart_y         116293 non-null float64
# dewpoint_x       116293 non-null int64
# dewpoint_y       116293 non-null int64
# heat_x           116293 non-null float64
# heat_y           116293 non-null float64
# preciplast30     116293 non-null float64
# preciplast7      116293 non-null float64
# preciplast90     116293 non-null float64
# preciptotal_x    116293 non-null float64
# preciptotal_y    116293 non-null float64
# resultdir_x      116293 non-null int64
# resultdir_y      116293 non-null int64
# resultspeed_x    116293 non-null float64
# resultspeed_y    116293 non-null float64
# sealevel_x       116293 non-null float64
# sealevel_y       116293 non-null float64
# stnpressure_x    116293 non-null float64
# stnpressure_y    116293 non-null float64
# tavg_x           116293 non-null float64
# tavg_y           116293 non-null float64
# tmax_x           116293 non-null int64
# tmax_y           116293 non-null int64
# tmin_x           116293 non-null int64
# tmin_y           116293 non-null int64
# wblast30         116293 non-null float64
# wblast7          116293 non-null float64
# wblast90         116293 non-null float64
# wetbulb_x        116293 non-null float64
# wetbulb_y        116293 non-null float64
# dtypes: float64(29), int64(13)
# memory usage: 38.2+ MB
# None

# %%
from sklearn.model_selection import train_test_split 
from sklearn.metrics import log_loss, accuracy_score
from collections import Counter

# %%
X = data.drop(['WnvPresent'], axis=1)
y = data[['WnvPresent']]

# %%
X.head()
# Out:
#             DayofYear  Species  Trap  Year  avgspeed_x  avgspeed_y  cool_x  \
# Date
# 2007-05-29        149        2     1  2007         6.5         7.4     9.0
# 2007-05-29        149        3     1  2007         6.5         7.4     9.0
# 2007-05-29        149        3     8  2007         6.5         7.4     9.0
# 2007-05-29        149        2    15  2007         6.5         7.4     9.0
# 2007-05-29        149        3    15  2007         6.5         7.4     9.0
#
#             cool_y  coollast30  coollast7    ...      tavg_y  tmax_x  tmax_y  \
# Date                                         ...
# 2007-05-29    12.0        35.0       31.0    ...         0.0      88      88
# 2007-05-29    12.0        35.0       31.0    ...         0.0      88      88
# 2007-05-29    12.0        35.0       31.0    ...         0.0      88      88
# 2007-05-29    12.0        35.0       31.0    ...         0.0      88      88
# 2007-05-29    12.0        35.0       31.0    ...         0.0      88      88
#
#             tmin_x  tmin_y  wblast30  wblast7  wblast90  wetbulb_x  wetbulb_y
# Date
# 2007-05-29      60      65    1149.0    412.0       0.0       65.0       66.0
# 2007-05-29      60      65    1149.0    412.0       0.0       65.0       66.0
# 2007-05-29      60      65    1149.0    412.0       0.0       65.0       66.0
# 2007-05-29      60      65    1149.0    412.0       0.0       65.0       66.0
# 2007-05-29      60      65    1149.0    412.0       0.0       65.0       66.0
#
# [5 rows x 41 columns]

# %%
y.head()
# Out:
#             WnvPresent
# Date
# 2007-05-29           0
# 2007-05-29           0
# 2007-05-29           0
# 2007-05-29           0
# 2007-05-29           0

# %%
sample = pd.DataFrame()
sample['Id'] = data_test['Id']
sample.head()
# Out:
#             Id
# Date
# 2008-06-11   1
# 2008-06-11   2
# 2008-06-11   3
# 2008-06-11   4
# 2008-06-11   5

# %%
data_test = data_test.drop('Id', 1)

# %% [markdown]
# ### Simple Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(X, y)
dt_pred = dt.predict(data_test)
dt_prob = dt.predict_proba(data_test)[:,1]
dt_nodes = dt.tree_.node_count
print ('Decision Tree')
print ('Number of Nodes: ', str(dt_nodes))
sample['WnvPresent_DecisionTree'] = dt_prob
# Out:
# Decision Tree
# ('Number of Nodes: ', '1817')

# %%
sample.head()
# Out:
#             Id  WnvPresent_DecisionTree
# Date
# 2008-06-11   1                      0.0
# 2008-06-11   2                      0.0
# 2008-06-11   3                      0.0
# 2008-06-11   4                      0.0
# 2008-06-11   5                      0.0

# %% [markdown]
# ### AdaBoost Classifier

# %%
adaboost = AdaBoostClassifier(
            base_estimator=DecisionTreeClassifier(max_depth=1), 
            algorithm='SAMME', n_estimators=1000, random_state=100)
adaboost.fit(X, y)
ada_pred = adaboost.predict(data_test)
ada_pred_proba = adaboost.predict_proba(data_test)[:,1]
print ('AdaBoost')
sample['WnvPresent_Ada'] = ada_pred_proba
sample.head()
# Out:
# /Users/aakashtandel/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoost
#             Id  WnvPresent_DecisionTree  WnvPresent_Ada
# Date
# 2008-06-11   1                      0.0        0.397339
# 2008-06-11   2                      0.0        0.396222
# 2008-06-11   3                      0.0        0.397339
# 2008-06-11   4                      0.0        0.364322
# 2008-06-11   5                      0.0        0.364322

# %% [markdown]
# ### Gradient Boost Classifier

# %%
gbc = GradientBoostingClassifier(
            max_depth=1, warm_start=True, 
            n_estimators=1000, random_state=100)
gbc.fit(X, y)
gbc_pred = gbc.predict(data_test)
gbc_pred_proba = gbc.predict_proba(data_test)[:,1]
print ('Gradient Boost')
sample['WnvPresent_gradientboost'] = gbc_pred_proba
sample.head()
# Out:
# Gradient Boost
#             Id  WnvPresent_DecisionTree  WnvPresent_Ada  \
# Date
# 2008-06-11   1                      0.0        0.397339
# 2008-06-11   2                      0.0        0.396222
# 2008-06-11   3                      0.0        0.397339
# 2008-06-11   4                      0.0        0.364322
# 2008-06-11   5                      0.0        0.364322
#
#             WnvPresent_gradientboost
# Date
# 2008-06-11                  0.005515
# 2008-06-11                  0.002596
# 2008-06-11                  0.006085
# 2008-06-11                  0.000530
# 2008-06-11                  0.000530

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

# %%
params = {'objective':'binary:logistic', 'max_depth':2, 'silent':1, 'eta':1}
num_rounds = 5
dtrain = xgb.DMatrix(X, label=y)
dtest = xgb.DMatrix(data_test)

# %%
boosted = xgb.train(params, dtrain, num_rounds)

# %%
# cv_xgb = xgb.cv(params = params, dtrain = dtrain, num_boost_round = 3000, nfold = 5,
#                 metrics = ['error'], # Make sure you enter metrics inside a list or you may encounter issues!
#                 early_stopping_rounds = 100) # Look for early stopping that minimizes error

# %%
# cv_xgb.tail()

# %%
# cv_xgb.shape

# %%
preds_prob = boosted.predict(dtest)
sample['WnvPresent_xgboost'] = preds_prob
sample.head()
# Out:
#             Id  WnvPresent_DecisionTree  WnvPresent_Ada  \
# Date
# 2008-06-11   1                      0.0        0.397339
# 2008-06-11   2                      0.0        0.396222
# 2008-06-11   3                      0.0        0.397339
# 2008-06-11   4                      0.0        0.364322
# 2008-06-11   5                      0.0        0.364322
#
#             WnvPresent_gradientboost  WnvPresent_xgboost
# Date
# 2008-06-11                  0.005515            0.019555
# 2008-06-11                  0.002596            0.003192
# 2008-06-11                  0.006085            0.019555
# 2008-06-11                  0.000530            0.003192
# 2008-06-11                  0.000530            0.003192

# %%
sample.shape
# Out:
# (116293, 5)

# %%
sample_xgboost = sample.copy(deep=True)
sample_xgboost = sample_xgboost.drop(['WnvPresent_DecisionTree', 'WnvPresent_Ada', 'WnvPresent_gradientboost'], 1)

# %%
sample_xgboost.set_index('Id', inplace=True)

# %%
sample_xgboost = sample_xgboost.sort_index(axis=1, ascending=True)

# %%
sample_xgboost.head()
# Out:
#     WnvPresent_xgboost
# Id
# 1             0.019555
# 2             0.003192
# 3             0.019555
# 4             0.003192
# 5             0.003192

# %%
sample_xgboost = sample_xgboost.rename(columns={'WnvPresent_xgboost': 'WnvPresent'})
sample_xgboost.head()
# Out:
#     WnvPresent
# Id
# 1     0.019555
# 2     0.003192
# 3     0.019555
# 4     0.003192
# 5     0.003192

# %%
sample_xgboost.to_csv('sample_xgboost.csv')
